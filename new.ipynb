# %%
import pandas as pd
import os

# %%
data = pd.read_csv('psg_data_train.csv')
data.head(35)
# Out:
#                  Joueur  Taille  Poids Apparitions  Minutes jouées  Buts  \
# 0           Sergio Rico     187     83           0              22     0
# 1       Alphonse Areola     190     80           3             301     0
# 2          Rémy Cabella     171     68           8             724     3
# 3        Benjamin André     180     76          14            1218     1
# 4        Jonathan David     175     70          15            1331     9
# 5            Adam Ounas     172     65           7             665     1
# 6        Jonathan Bamba     175     72          14            1256     4
# 7               Ismaily     177     82          11             968     2
# 8             Leny Yoro     190      0           1             100     0
# 9           Tiago Djalo     190      0          13            1109     2
# 10          Angel Gomes     161     61          14            1107     1
# 11         Yusuf Yazici     183     74           3             202     1
# ...

# %%
data.describe()
# Out:
#            Taille       Poids  Minutes jouées       Buts  Passes Décisives  \
# count   78.000000   78.000000       78.000000  78.000000         78.000000
# mean   173.858974   66.730769      783.923077   1.192308          0.794872
# std     35.466364   37.405352     1144.227270   1.967645          1.282844
# min      0.000000    0.000000        0.000000   0.000000          0.000000
# 25%    175.000000   67.000000      251.750000   0.000000          0.000000
# 50%    180.500000   72.000000      745.000000   0.000000          0.000000
# 75%    185.000000   77.000000     1100.000000   1.000000          1.000000
# max    198.000000  301.000000     9983.000000   9.000000          5.000000
#
#            Jaune      Rouge  Tirs par match  Précision  Duels aériens gagnés  \
# count  78.000000  78.000000       78.000000  78.000000             78.000000
# mean    1.260256   1.721795        1.232051  78.121795              2.063974
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Joueur                78 non-null     object
#  1   Taille                78 non-null     int64
#  2   Poids                 78 non-null     int64
#  3   Apparitions           78 non-null     object
#  4   Minutes jouées        78 non-null     int64
#  5   Buts                  78 non-null     int64
#  6   Passes Décisives      78 non-null     int64
#  7   Jaune                 78 non-null     float64
#  8   Rouge                 78 non-null     float64
#  9   Tirs par match        78 non-null     float64
#  10  Précision             78 non-null     float64
#  11  Duels aériens gagnés  78 non-null     float64
#  12  Homme du match        77 non-null     float64
#  13  Note                  76 non-null     float64
#  14  Décision              75 non-null     float64
# ...
